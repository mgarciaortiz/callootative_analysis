# %%
from covid19 import plotFitData, plotSIRModelForData
from data_plotter import plotRealData

# %%
countries_predefined = ["France", "Italy", "Spain", "Germany", "Portugal", "United_States_of_America", "United_Kingdom", "China", "Japan", "South_Korea", "Iran"]

# %%
csvFile = "data_covid19.csv"
fileFormat = 1
dataType = "cases"
plot = True
nprev = 3
ndiscard = 0
verbose = 1
plotFitData(["France"], csvFile, fileFormat, dataType, plot, nprev, ndiscard, verbose)
# Out:
# >>>>>> Could not compute exponential fit for France
# *******************************************
# Country                     =  France
# Last available date         =  2020-03-29 00:00:00
# Logisitic Fit               =  (array([5.29434199e+00, 8.95850980e+01, 8.71002261e+04]), array([[8.07406134e-03, 4.29423647e-02, 3.99563684e+02],
#        [4.29423647e-02, 2.53253236e-01, 2.40587551e+03],
#        [3.99563684e+02, 2.40587551e+03, 2.30125650e+07]]))
# Log. Errors                 =  [0.08985578075614986, 0.5032427209249939, 4797.141340920115]
# Number of days from 1st Jan =  157
# Predicted date for inflection =  2020-03-31 00:00:00
# Predicted date for saturation =  2020-06-06 00:00:00
# *******************************************
# >>>>>> Could not compute exponential fit for France
# *******************************************
# Country                     =  France
# Last available date         =  2020-03-28 00:00:00
# ...

# %%
plotFitData(["Italy","Spain"], csvFile, fileFormat, "deaths", plot, nprev, ndiscard, verbose)
# Out:
# /home/ac254769/.local/lib/python3.7/site-packages/scipy/optimize/minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# *******************************************
# Country                     =  Italy
# Last available date         =  2020-03-29 00:00:00
# Logisitic Fit               =  (array([4.80477940e+00, 8.46713652e+01, 1.47474279e+04]), array([[5.08194590e-03, 1.51282727e-02, 2.13740625e+01],
#        [1.51282727e-02, 5.29164982e-02, 7.56244214e+01],
#        [2.13740625e+01, 7.56244214e+01, 1.09806011e+05]]))
# Log. Errors                 =  [0.07128776826447465, 0.2300358628011642, 331.369899951063]
# Number of days from 1st Jan =  134
# Predicted date for inflection =  2020-03-26 00:00:00
# Predicted date for saturation =  2020-05-14 00:00:00
# *******************************************
# *******************************************
# Country                     =  Italy
# ...

# %%
plotRealData(countries_predefined, csvFile, fileFormat, ndiscard, "cases")

# %%
initial_values = [150000, 2, 0]
countries = ["France"]
plotSIRModelForData(countries, csvFile, initial_values)
# Out:
#       fun: 1019.1136289830254
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([1.32279743e+10, 1.86510877e+04])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 249
#       nit: 10
#    status: 2
#   success: False
#         x: array([1.43279236e-06, 9.72829857e-03])
# country = France,
#  beta = 0.00000143,
#  gamma = 0.00972830,
#  r_0 = 0.00014728
