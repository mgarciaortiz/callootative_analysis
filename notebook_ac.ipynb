# %%
from covid19 import plotFitData, plotSIRModelForData
from data_plotter import plotRealData

# %%
countries_predefined = ["France", "Italy", "Spain", "Germany", "Portugal", "United_States_of_America", "United_Kingdom", "China", "Japan", "South_Korea", "Iran"]

# %%
csvFile = "data_covid19.csv"
fileFormat = 1
dataType = "Cases"
plot = True
nprev = 3
ndiscard = 0
verbose = 1
plotFitData(["France"], csvFile, fileFormat, dataType, plot, nprev, ndiscard, verbose)
# Out:
# *******************************************
# Country                     =  France
# Last available date         =  2020-03-24 00:00:00
# Logisitic Fit               =  (array([4.46606714e+00, 8.35359889e+01, 4.06876724e+04]), array([[1.21865533e-02, 5.75407757e-02, 2.84225075e+02],
#        [5.75407757e-02, 3.03088257e-01, 1.52788891e+03],
#        [2.84225075e+02, 1.52788891e+03, 7.76127536e+06]]))
# Log. Errors                 =  [0.11039272321820266, 0.5505345189462975, 2785.9065592919305]
# Number of days from 1st Jan =  132
# Predicted date for inflection =  2020-03-25 00:00:00
# Predicted date for saturation =  2020-05-12 00:00:00
# *******************************************
# >>>>>> Could not compute exponential fit for France
# *******************************************
# Country                     =  France
# Last available date         =  2020-03-23 00:00:00
# Logisitic Fit               =  (array([3.97218975e+00, 8.05747594e+01, 2.72409803e+04]), array([[1.55089444e-03, 5.49670645e-03, 1.84392025e+01],
#        [5.49670645e-03, 2.22936893e-02, 7.60554471e+01],
#        [1.84392025e+01, 7.60554471e+01, 2.62387645e+05]]))
# Log. Errors                 =  [0.03938139717539344, 0.14931071379655375, 512.2378788926108]
# Number of days from 1st Jan =  121
# Predicted date for inflection =  2020-03-22 00:00:00
# Predicted date for saturation =  2020-05-01 00:00:00
# *******************************************
# *******************************************
# Country                     =  France
# Last available date         =  2020-03-22 00:00:00
# Logisitic Fit               =  (array([3.98640054e+00, 8.06557384e+01, 2.75543220e+04]), array([[2.17060482e-03, 9.00389131e-03, 3.22089858e+01],
#        [9.00389131e-03, 4.20516360e-02, 1.53360265e+02],
#        [3.22089858e+01, 1.53360265e+02, 5.64266460e+05]]))
# Log. Errors                 =  [0.04658975019413909, 0.20506495547373962, 751.1767166370229]
# Number of days from 1st Jan =  125
# Predicted date for inflection =  2020-03-22 00:00:00
# Predicted date for saturation =  2020-05-05 00:00:00
# *******************************************
# >>>>>> Could not compute exponential fit for France
# *******************************************
# Country                     =  France
# Last available date         =  2020-03-21 00:00:00
# Logisitic Fit               =  (array([3.90639841e+00, 8.01494026e+01, 2.55641449e+04]), array([[2.62666827e-03, 1.17194505e-02, 4.07439700e+01],
#        [1.17194505e-02, 5.85295504e-02, 2.07572515e+02],
#        [4.07439700e+01, 2.07572515e+02, 7.42117312e+05]]))
# Log. Errors                 =  [0.05125103185379837, 0.24192881275525535, 861.462310482311]
# Number of days from 1st Jan =  127
# Predicted date for inflection =  2020-03-22 00:00:00
# Predicted date for saturation =  2020-05-07 00:00:00
# *******************************************

# %%
plotFitData(["Italy","Spain"], csvFile, fileFormat, "Deaths", plot, nprev, ndiscard, verbose)
# Out:
# *******************************************
# Country                     =  Italy
# Last available date         =  2020-03-24 00:00:00
# Logisitic Fit               =  (array([4.42316497e+00, 8.28527120e+01, 1.19854780e+04]), array([[6.83141475e-03, 2.94048218e-02, 4.17920517e+01],
#        [2.94048218e-02, 1.42119222e-01, 2.06019561e+02],
#        [4.17920517e+01, 2.06019561e+02, 3.01195701e+05]]))
# Log. Errors                 =  [0.08265237295284088, 0.376987031944881, 548.8129931836861]
# Number of days from 1st Jan =  127
# Predicted date for inflection =  2020-03-24 00:00:00
# Predicted date for saturation =  2020-05-07 00:00:00
# *******************************************
# *******************************************
# Country                     =  Italy
# Last available date         =  2020-03-23 00:00:00
# Logisitic Fit               =  (array([4.45518692e+00, 8.30745533e+01, 1.23518731e+04]), array([[9.60123377e-03, 4.88278892e-02, 7.53592599e+01],
#        [4.88278892e-02, 2.75830740e-01, 4.34552099e+02],
#        [7.53592599e+01, 4.34552099e+02, 6.89475915e+05]]))
# Log. Errors                 =  [0.09798588556785415, 0.5251959062540316, 830.3468645251012]
# Number of days from 1st Jan =  125
# Predicted date for inflection =  2020-03-25 00:00:00
# Predicted date for saturation =  2020-05-05 00:00:00
# *******************************************
# >>>>>> Could not compute exponential fit for Italy
# *******************************************
# Country                     =  Italy
# Last available date         =  2020-03-22 00:00:00
# Logisitic Fit               =  (array([4.34370387e+00, 8.22314886e+01, 1.09664519e+04]), array([[1.20502272e-02, 6.28363173e-02, 8.90957089e+01],
#        [6.28363173e-02, 3.63471323e-01, 5.26077837e+02],
#        [8.90957089e+01, 5.26077837e+02, 7.66709603e+05]]))
# Log. Errors                 =  [0.10977352696571804, 0.6028858289445526, 875.6195540682659]
# Number of days from 1st Jan =  126
# Predicted date for inflection =  2020-03-24 00:00:00
# Predicted date for saturation =  2020-05-06 00:00:00
# *******************************************
# >>>>>> Could not compute exponential fit for Italy
# *******************************************
# Country                     =  Italy
# Last available date         =  2020-03-21 00:00:00
# Logisitic Fit               =  (array([3.98016047e+00, 7.97419240e+01, 7.66242734e+03]), array([[6.72039300e-03, 2.82296018e-02, 2.82532800e+01],
#        [2.82296018e-02, 1.33368176e-01, 1.36098461e+02],
#        [2.82532800e+01, 1.36098461e+02, 1.40098481e+05]]))
# Log. Errors                 =  [0.08197800317036841, 0.3651960791836991, 374.2973166865278]
# Number of days from 1st Jan =  118
# Predicted date for inflection =  2020-03-21 00:00:00
# Predicted date for saturation =  2020-04-28 00:00:00
# *******************************************
# /home/ac254769/.local/lib/python3.7/site-packages/scipy/optimize/minpack.py:787: OptimizeWarning: Covariance of the parameters could not be estimated
#   category=OptimizeWarning)
# *******************************************
# Country                     =  Spain
# Last available date         =  2020-03-24 00:00:00
# Logisitic Fit               =  (array([3.20240126e+00, 8.61308514e+01, 7.96298639e+03]), array([[5.31313562e-03, 4.30246962e-02, 6.94395903e+01],
#        [4.30246962e-02, 3.81042885e-01, 6.26606045e+02],
#        [6.94395903e+01, 6.26606045e+02, 1.03514332e+06]]))
# Log. Errors                 =  [0.07289125885277281, 0.617286711929354, 1017.4199334284777]
# Number of days from 1st Jan =  114
# Predicted date for inflection =  2020-03-28 00:00:00
# Predicted date for saturation =  2020-04-24 00:00:00
# *******************************************
# *******************************************
# Country                     =  Spain
# Last available date         =  2020-03-23 00:00:00
# Logisitic Fit               =  (array([3.14027194e+00, 8.53667194e+01, 6.69792498e+03]), array([[8.59169949e-03, 7.42592005e-02, 1.04818616e+02],
#        [7.42592005e-02, 7.01319373e-01, 1.00821077e+03],
#        [1.04818616e+02, 1.00821077e+03, 1.45563931e+06]]))
# Log. Errors                 =  [0.09269142077718538, 0.8374481313822832, 1206.498780089103]
# Number of days from 1st Jan =  113
# Predicted date for inflection =  2020-03-27 00:00:00
# Predicted date for saturation =  2020-04-23 00:00:00
# *******************************************
# *******************************************
# Country                     =  Spain
# Last available date         =  2020-03-22 00:00:00
# Logisitic Fit               =  (array([2.94708238e+00, 8.31968339e+01, 4.06619249e+03]), array([[1.13666352e-02, 7.81080468e-02, 6.64360883e+01],
#        [7.81080468e-02, 5.88367094e-01, 5.10224640e+02],
#        [6.64360883e+01, 5.10224640e+02, 4.44774923e+05]]))
# Log. Errors                 =  [0.10661442291673344, 0.7670509067927356, 666.9144797083105]
# Number of days from 1st Jan =  112
# Predicted date for inflection =  2020-03-25 00:00:00
# Predicted date for saturation =  2020-04-22 00:00:00
# *******************************************
# *******************************************
# Country                     =  Spain
# Last available date         =  2020-03-21 00:00:00
# Logisitic Fit               =  (array([   2.60422992,   80.3960427 , 2140.5320525 ]), array([[1.06616818e-02, 4.96627082e-02, 2.20093214e+01],
#        [4.96627082e-02, 2.57533100e-01, 1.16361594e+02],
#        [2.20093214e+01, 1.16361594e+02, 5.29661515e+04]]))
# Log. Errors                 =  [0.10325542007458388, 0.5074771917376109, 230.14376269975955]
# Number of days from 1st Jan =  102
# Predicted date for inflection =  2020-03-22 00:00:00
# Predicted date for saturation =  2020-04-12 00:00:00
# *******************************************

# %%
plotRealData(countries_predefined, csvFile, fileFormat, ndiscard, "Cases")

# %%
initial_values = [90000, 2, 0]
countries = ["France"]
plotSIRModelForData(countries, csvFile, initial_values)
# Out:
#       fun: 287.59256811478684
#  hess_inv: <2x2 LbfgsInvHessProduct with dtype=float64>
#       jac: array([3.05479226e+09, 1.46823655e+04])
#   message: b'ABNORMAL_TERMINATION_IN_LNSRCH'
#      nfev: 195
#       nit: 6
#    status: 2
#   success: False
#         x: array([2.79977969e-06, 3.90143377e-02])
# country = France,
#  beta = 0.00000280,
#  gamma = 0.03901434,
#  r_0 = 0.00007176
